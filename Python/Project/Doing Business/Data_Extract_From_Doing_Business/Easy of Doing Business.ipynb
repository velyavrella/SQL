# %% [markdown]
# ### Import Module

# %%
import pandas as pd # olah dan analisis data

# %% [markdown]
# ### Input Data
# Global: Ease of doing business score (DB17-20 methodology). Data diperoleh dari website https://databank.worldbank.org/source/doing-business#.

# %%
data_df = pd.read_csv('./Data.csv', index_col = 'Year') # memuat file csv sebagai data frame
data_df.head() # tampilkan 5 baris pertama
# Out:
#       Australia  Brazil  China  India  Indonesia  Japan  Malaysia  Myanmar  \
# Year
# 2016       80.4    55.6   63.1   54.5       62.1   77.5      78.6     42.1
# 2017       80.2    55.2   64.6   55.9       64.7   77.9      78.3     42.7
# 2018       80.8    55.6   65.2   60.9       66.9   78.0      78.8     43.0
# 2019       80.7    58.6   74.0   67.5       68.2   78.0      81.3     43.5
# 2020       81.2    59.1   77.9   71.0       69.6   78.0      81.5     46.8
#
#       Philippines  Singapore  Saudi Arabia  Thailand  United Kingdom  \
# Year
# 2016         58.2       84.9          59.2      71.9            83.3
# 2017         59.3       85.4          59.4      72.8            83.3
# 2018         59.3       85.6          62.1      78.5            83.2
# 2019         60.9       85.8          63.8      79.5            83.6
# 2020         62.8       86.2          71.6      80.1            83.5
#
#       United States  Vietnam
# Year
# 2016           83.6     62.6
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 2016 to 2020
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Australia       5 non-null      float64
#  1   Brazil          5 non-null      float64
#  2   China           5 non-null      float64
#  3   India           5 non-null      float64
#  4   Indonesia       5 non-null      float64
#  5   Japan           5 non-null      float64
#  6   Malaysia        5 non-null      float64
#  7   Myanmar         5 non-null      float64
#  8   Philippines     5 non-null      float64
#  9   Singapore       5 non-null      float64
#  10  Saudi Arabia    5 non-null      float64
#  11  Thailand        5 non-null      float64
#  12  United Kingdom  5 non-null      float64
#  13  United States   5 non-null      float64
#  14  Vietnam         5 non-null      float64
# dtypes: float64(15)
# memory usage: 640.0 bytes

# %% [markdown]
# ### Statistika Deskriptif

# %%
data_df.describe()
# Out:
#        Australia     Brazil      China      India  Indonesia      Japan  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   80.660000  56.820000  68.960000  61.960000  66.300000  77.880000
# std     0.384708   1.868689   6.572899   7.174817   2.960574   0.216795
# min    80.200000  55.200000  63.100000  54.500000  62.100000  77.500000
# 25%    80.400000  55.600000  64.600000  55.900000  64.700000  77.900000
# 50%    80.700000  55.600000  65.200000  60.900000  66.900000  78.000000
# 75%    80.800000  58.600000  74.000000  67.500000  68.200000  78.000000
# max    81.200000  59.100000  77.900000  71.000000  69.600000  78.000000
#
#        Malaysia    Myanmar  Philippines  Singapore  Saudi Arabia   Thailand  \
# count   5.00000   5.000000     5.000000   5.000000      5.000000   5.000000
# mean   79.70000  43.620000    60.100000  85.580000     63.220000  76.560000
# std     1.56365   1.848513     1.790251   0.481664      5.063793   3.898461
# ...

# %% [markdown]
# #### Menghilangkan kolom beberapa negara

# %%
data_df.drop(columns=['Australia','Japan','United Kingdom', 'Brazil','China'], inplace=True) # menghapus kolom bernama 'Id'
data_df.head() # tampilkan 5 baris pertama
# Out:
#       India  Indonesia  Malaysia  Myanmar  Philippines  Singapore  \
# Year
# 2016   54.5       62.1      78.6     42.1         58.2       84.9
# 2017   55.9       64.7      78.3     42.7         59.3       85.4
# 2018   60.9       66.9      78.8     43.0         59.3       85.6
# 2019   67.5       68.2      81.3     43.5         60.9       85.8
# 2020   71.0       69.6      81.5     46.8         62.8       86.2
#
#       Saudi Arabia  Thailand  United States  Vietnam
# Year
# 2016          59.2      71.9           83.6     62.6
# 2017          59.4      72.8           83.6     65.3
# 2018          62.1      78.5           83.6     67.0
# 2019          63.8      79.5           83.6     68.6
# 2020          71.6      80.1           84.0     69.8

# %% [markdown]
# ### Visualisasi Data

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# %%
data_df.plot()
plt.title('Ease of Doing Business Score')
plt.xticks(data_df.index)
plt.legend(loc = 'upper left')
plt.tight_layout()
