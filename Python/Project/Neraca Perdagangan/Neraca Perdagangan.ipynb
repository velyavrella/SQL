# %% [markdown]
# ### Import Module

# %%
import pandas as pd # olah dan analisis data

# %% [markdown]
# ### Input Data
# Data merupakan Neraca Perdagangan setiap Provinsi di Indonesia yang diperoleh dari website https://satudata.kemendag.go.id/provincial-trade-balance

# %%
data_df = pd.read_csv('./Data.csv') # memuat file csv sebagai data frame
data_df # tampilkan 5 baris pertama
# Out:
#                 Provinsi       2017       2018
# 0                   ACEH   -3859322    3506934
# 1         SUMATERA UTARA     808868   33852926
# 2         SUMATERA BARAT  -18112734    5130044
# 3                   RIAU    -462642  -57000948
# 4                  JAMBI   11295867    3162472
# 5       SUMATERA SELATAN    8236954  -11413033
# 6               BENGKULU    2488442    2949890
# 7                LAMPUNG   19464819    4981874
# 8   KEP. BANGKA BELITUNG   -1641247   -3070408
# 9              KEP. RIAU   -3387187   -8981640
# 10           DKI JAKARTA   45404435   34045189
# 11            JAWA BARAT  -46795574  177903066
# 12           JAWA TENGAH  -15776293  113662955
# 13         DI YOGYAKARTA    2812901  -11153855
# 14            JAWA TIMUR  433417213   70875329
# 15                BANTEN   23063788   87516228
# 16                  BALI  -44592223  -26747584
# 17   NUSA TENGGARA BARAT    3439850  -12628140
# 18   NUSA TENGGARA TIMUR   -2363986   -8885351
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Provinsi  34 non-null     object
#  1   2017      34 non-null     int64
#  2   2018      34 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 944.0+ bytes

# %% [markdown]
# ### Statistika Deskriptif

# %%
data_df.describe()
# Out:
#                2017          2018
# count  3.400000e+01  3.400000e+01
# mean   1.217111e+07  1.556214e+07
# std    7.608203e+07  5.632087e+07
# min   -4.679557e+07 -5.700095e+07
# 25%   -2.529851e+06 -1.092684e+07
# 50%   -5.420480e+05 -1.973820e+06
# 75%    3.283113e+06  4.613139e+06
# max    4.334172e+08  2.181224e+08

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# %%
fig, ax = plt.subplots(figsize =(8, 5))
ax.barh(data_df['Provinsi'],data_df['2018'], color='yellowgreen')

# # Add annotation to bars
# for i in ax.patches:
#     plt.text(i.get_width()+0.2, i.get_y()+0.5,
#              str(round((i.get_width()), 2)),
#              fontsize = 10, fontweight ='bold',
#              color ='grey')
 
# Add Plot Title
ax.set_title('Neraca Perdagangan tiap Provinsi di Indonesia',
             loc ='left')


plt.show()
