# %% [markdown]
# ### Import Module

# %%
import pandas as pd

# %% [markdown]
# ### Input Data
# Data ini merupakan Realisasi Investasi Penanaman Modal Dalam Negeri Menurut Provinsi (Investasi) (Milyar Rupiah), 2018-2020 yang diperoleh dari website https://www.bps.go.id/indicator/13/793/1/realisasi-investasi-penanaman-modal-dalam-negeri-menurut-provinsi-investasi-.html

# %%
data_df = pd.read_csv('./Data.csv', index_col = 'Provinsi') # memuat file csv sebagai data frame
data_df # tampilkan 5 baris pertama
# Out:
#                          2018     2019     2020
# Provinsi
# ACEH                    970.0   3606.9   8241.1
# SUMATERA UTARA         8371.8  19749.0  18189.5
# SUMATERA BARAT         2309.4   3026.6   3106.2
# RIAU                   9056.4  26292.2  34117.8
# JAMBI                  2876.5   4437.4   3511.7
# SUMATERA SELATAN       9519.8  16921.1  15824.5
# BENGKULU               4902.8   5458.1   5399.2
# LAMPUNG               12314.7   2428.9   7120.5
# KEP. BANGKA BELITUNG   3112.9   2915.2   1863.8
# KEP. RIAU              4386.0   5656.4  14249.0
# DKI JAKARTA           49097.4  62094.8  42954.7
# JAWA BARAT            42278.2  49284.2  51400.5
# JAWA TENGAH           27474.9  18654.7  30606.1
# DI YOGYAKARTA          6131.7   6298.8   2683.4
# JAWA TIMUR            33333.1  45452.7  55660.6
# BANTEN                18637.6  20708.4  31145.7
# BALI                   1548.8   7393.2   5432.7
# NUSA TENGGARA BARAT    4135.1   3519.0   6582.4
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, ACEH to PAPUA
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2018    34 non-null     float64
#  1   2019    34 non-null     float64
#  2   2020    34 non-null     float64
# dtypes: float64(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ### Statistika Deskriptif

# %%
data_df.describe()
# Out:
#                2018          2019          2020
# count     34.000000     34.000000     34.000000
# mean    9664.847059  11367.605882  12162.808824
# std    12171.564012  14785.179008  15184.947685
# min       50.900000    283.200000    252.900000
# 25%     2398.750000   3149.700000   2758.075000
# 50%     4353.050000   5557.250000   5330.250000
# 75%     9861.350000  15206.075000  15430.625000
# max    49097.400000  62094.800000  55660.600000

# %% [markdown]
# #### 5 Provinsi dengan PMDN Terbesar

# %%
data_df['2020'].sort_values(ascending=False).head()
# Out:
# Provinsi
# JAWA TIMUR     55660.6
# JAWA BARAT     51400.5
# DKI JAKARTA    42954.7
# RIAU           34117.8
# BANTEN         31145.7
# Name: 2020, dtype: float64

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# %%
data = data_df['2020'].sort_values(ascending = False)

# %%
plt.figure(figsize=(20,6))
data.plot.bar(color = 'orange')
plt.title('Penanaman Modal Dalam Negeri', size=16)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()
