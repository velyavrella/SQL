# %% [markdown]
# ### Import Module

# %%
import pandas as pd

# %% [markdown]
# ### Input Data
# Data ini merupakan Realisasi Investasi Penanaman Modal Luar Negeri Menurut Provinsi (Juta US$), 2018-2020 yang diperoleh dari website https://www.bps.go.id/indicator/13/1840/1/realisasi-investasi-penanaman-modal-luar-negeri-menurut-provinsi.html

# %%
data_df = pd.read_csv('./Data.csv', index_col = 'Provinsi') # memuat file csv sebagai data frame
data_df # tampilkan 5 baris pertama
# Out:
#                         2018    2019    2020
# Provinsi
# ACEH                    71.2   137.5    51.1
# SUMATERA UTARA        1227.6   379.5   974.8
# SUMATERA BARAT         180.8   157.1   125.6
# RIAU                  1032.9  1034.0  1078.0
# JAMBI                  101.9    54.6    27.0
# SUMATERA SELATAN      1078.6   736.5  1543.9
# BENGKULU               136.6   144.8   192.3
# LAMPUNG                132.3   155.2   498.4
# KEP. BANGKA BELITUNG    46.3    88.7    48.4
# KEP. RIAU              831.3  1363.4  1649.4
# DKI JAKARTA           4857.7  4123.0  3613.3
# JAWA BARAT            5573.5  5881.0  4793.7
# JAWA TENGAH           2372.7  2723.2  1363.6
# DI YOGYAKARTA           81.3    14.6     9.7
# JAWA TIMUR            1333.4   866.3  1575.5
# BANTEN                2827.3  1868.2  2143.6
# BALI                  1002.5   426.0   293.3
# NUSA TENGGARA BARAT    251.6   270.7   302.1
# NUSA TENGGARA TIMUR    100.4   126.8    81.3
# KALIMANTAN BARAT       491.9   532.3   759.3
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, ACEH to PAPUA
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2018    34 non-null     float64
#  1   2019    34 non-null     float64
#  2   2020    34 non-null     float64
# dtypes: float64(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ### Statistika Deskriptif

# %%
data_df.describe()
# Out:
#               2018         2019         2020
# count    34.000000    34.000000    34.000000
# mean    862.005882   829.658824   843.135294
# std    1283.211619  1247.824316  1105.618021
# min       8.000000    10.100000     6.500000
# 25%     108.725000   139.325000    92.375000
# 50%     427.350000   337.750000   297.700000
# 75%    1025.300000   976.025000  1339.850000
# max    5573.500000  5881.000000  4793.700000

# %% [markdown]
# #### 5 Provinsi dengan PMDN Terbesar

# %%
data_df['2020'].sort_values(ascending=False).head()
# Out:
# Provinsi
# JAWA BARAT         4793.7
# DKI JAKARTA        3613.3
# MALUKU UTARA       2409.0
# BANTEN             2143.6
# SULAWESI TENGAH    1779.0
# Name: 2020, dtype: float64

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# %%
data = data_df['2020'].sort_values(ascending = False)

# %%
plt.figure(figsize=(20,6))
data.plot.bar(color = 'green')
plt.title('Penanaman Modal Luar Negeri', size=16)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.tight_layout()
